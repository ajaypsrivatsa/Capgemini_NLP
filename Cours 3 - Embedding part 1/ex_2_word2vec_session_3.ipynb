# %% [markdown]
# # WORD2VEC
#
# Session 3 - Exercice 2

# %% [markdown]
# # Load Packages
#
# __Load the necessary packages before starting your work__

# %%
# Load file from drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("drive/MyDrive/NLP @ X_HEC - 2K21/Cours 3 - Embedding part 1/") # path to your drive folder

# %%
# !pwd
# !ls
# Out:
# /content/drive/MyDrive/NLP @ X_HEC - 2K21/Cours 3 - Embedding part 1
# data  ex_2_word2vec_session_3.ipynb

# %%
# Classic data manipulation libraries
import re
import ast
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Visualization libraries
import seaborn as sns

# NLP Libraries
import gensim
from gensim.test.utils import get_tmpfile
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# Define parameters for notebook import
# %matplotlib inline
pd.set_option('display.max_columns', 500)

# %% [markdown]
# # Load Data

# %% [markdown]
# __1- Get the data and look at its shape__

# %%
# !ls data/
# Out:
# clean_text_scrapped_data_2021.csv

# %%
path_to_your_dataset = 'data/clean_text_scrapped_data_2021.csv'

reviews = pd.read_csv(path_to_your_dataset,
                      low_memory=False,
                      parse_dates=['rating_date', 'diner_date']
                     )

# %%
# Take only a limited number of our reviews to increase speed / reduce process time
reviews = reviews.sample(30000)
# Out:
#         Unnamed: 0   0                                        answer_text  \
# 146706      624306 NaN  ['Hi! We are really sorry you had a bad delive...
# 257201       63408 NaN  ['Dear Hadders1401, ', 'Thank you for taking t...
# 90945      1051940 NaN  ['Dear Jon M,', 'Thank you so much for sharing...
# 225695      892292 NaN  ['Hi JT14', 'Thank you very much for your love...
# 168652      551886 NaN  ['Hello Melanie T,', 'Super happy you and your...
#
#                                                   content diner_date  \
# 146706  ['Have eaten here before and trusted it was he... 2018-12-01
# 257201  ['We visited the grill on Saturday lunch time ... 2015-06-01
# 90945   ['Catered to my gluten allergy. ', 'Staff were... 2020-02-01
# 225695  ['Brilliant place. Delicious food, lovely staf... 2018-07-01
# 168652  ['Very good quality Lobster, no bookings so ha... 2016-07-01
#
#                           id_comment           id_resto  \
# 146706   g186338-d2371957-r639446852   g186338-d2371957
# 257201    g186338-d720748-r278508969    g186338-d720748
# 90945   g186338-d15123539-r743227715  g186338-d15123539
# 225695   g186338-d7140024-r597890619   g186338-d7140024
# 168652   g186338-d3468435-r388483858   g186338-d3468435
#
#               other_ratings_category other_ratings_value  rating rating_date  \
# 146706                            []                  []     1.0  2018-12-13
# 257201                            []                  []     5.0  2015-06-07
# 90945                             []                  []     5.0  2020-02-05
# 225695  ['Value', 'Service', 'Food']  ['50', '50', '50']     5.0  2018-07-20
# 168652                            []                  []     5.0  2016-07-02
#
#                               resto  \
# 146706               Wild_Food_Cafe
# 257201  The_Grill_at_The_Dorchester
# 90945                        Kahani
# 225695                Senor_Ceviche
# 168652          Burger_Lobster_Soho
#
#                                                 resto_url  \
# 146706  /Restaurant_Review-g186338-d2371957-Reviews-Wi...
# 257201  /Restaurant_Review-g186338-d720748-Reviews-The...
# 90945   /Restaurant_Review-g186338-d15123539-Reviews-K...
# 225695  /Restaurant_Review-g186338-d7140024-Reviews-Se...
# 168652  /Restaurant_Review-g186338-d3468435-Reviews-Bu...
#
#                                       reviewer_info_sup  \
# 146706      [['pencil-paper', '3'], ['thumbs-up', '4']]
# 257201    [['pencil-paper', '20'], ['thumbs-up', '16']]
# 90945                           [['pencil-paper', '1']]
# 225695  [['pencil-paper', '400'], ['thumbs-up', '383']]
# 168652    [['pencil-paper', '12'], ['thumbs-up', '10']]
#
#                       reviewer_origin reviewer_pseudo  \
# 146706     ['London, United Kingdom']       Ddgd124dg
# 257201   ['Nuneaton, United Kingdom']     hadders1401
# 90945                              []     F7849WWjonm
# 225695                     ['London']            JT14
# 168652  ['Gateshead, United Kingdom']       Melanie T
#
#                                          title  \
# 146706  A takeaway delivery big disappointment
# 257201                       So Sophisticated
# 90945       Birthday treat from a great friend
# 225695                               Fantastic
# 168652                              Brilliant
#
#                                                       url  Day_of_week  \
# 146706  https://www.tripadvisor.com/ShowUserReviews-g1...            3
# 257201  https://www.tripadvisor.com/ShowUserReviews-g1...            6
# 90945   https://www.tripadvisor.com/ShowUserReviews-g1...            2
# 225695  https://www.tripadvisor.com/ShowUserReviews-g1...            4
# 168652  https://www.tripadvisor.com/ShowUserReviews-g1...            5
#
#                                             clean_content
# 146706  ["'have", 'eaten', 'trusted', 'healthy', 'howe...
# 257201  ["'we", 'visited', 'grill', 'saturday', 'lunch...
# 90945   ["'catered", 'gluten', 'allergy', "'staff", 'f...
# 225695  ["'brilliant", 'place', 'delicious', 'food', '...
# 168652  ["'very", 'good', 'quality', 'lobster', 'booki...

# %% [markdown]
# __2- Look into few lines of your data and see variables types__

# %%
# code here

# %% [markdown]
# __3- If there is something not normal to you, correct it; otherwise going on to the next section__

# %%
# code here

# %% [markdown]
# __4- Get the reviews of Capgemini to begin__
#
# _(later you could try with you own dataset or with the full students data)_

# %%
# code here

# %% [markdown]
# __5- Try to see if there's not something else to do__

# %%
# code here

# %% [markdown]
# __6- Create your corpus (it is a list of the reviews)__

# %%
# code here

# %% [markdown]
# # Building your own Word2Vec

# %% [markdown]
# __1- Load gensim package__

# %%
# code here (if you forgot to load the package at the beginning)

# %% [markdown]
# __2- Create a temporary file by giving an extension and make sure you add ".model" as extension__

# %%
# code here

# %% [markdown]
# __3- Instantiate your word2vec model__

# %%
# code here

# %% [markdown]
# __4- Define the vocabulary of your model__

# %%
# code here

# %% [markdown]
# __5- Train your word2vec model__

# %%
# code here

# %% [markdown]
# __6- Save your word2vec model; give the same path as in your temporary file__

# %%
# code here

# %% [markdown]
# __Congratulations, you've built your first word2vec model !!!__

# %% [markdown]
# __7- Try to repeat the previous steps and change the values of hyperparameters from the model instatiation step__

# %%
# code here

# %% [markdown]
# __8- Load the model you've saved (from the same path as saving path)__

# %%
# code here

# %% [markdown]
# __9- Get the weight vector of a word; this is the vector (of numerical) representation of your word__

# %%
# code here

# %% [markdown]
# __10- Get the similarity of some words from your laoded model__

# %%
# code here

# %% [markdown]
# # Create Word Embedding of Wors

# %% [markdown]
# __1- Get the embedding matrix of your corpus__

# %%
# code here

# %% [markdown]
# __2- Transform it to a pandas DataFrame and look into few lines of you embedding matrix__

# %%
# code here

# %% [markdown]
# # Discovering Knowledge With Embedding Matrix

# %% [markdown]
# ## 1- Dimension Reduction (PCA)

# %% [markdown]
# __1.1- Instantiate a PCA with whatever number of components that you want__

# %%
# code here

# %% [markdown]
# __1.2- Fit your PCA to your data; make sure your words are the rows of your data__

# %%
# code here

# %% [markdown]
# __1.3- Get the explained variance ratio of your PCA__

# %%
# code here

# %% [markdown]
# __1.4- Apply your PCA to your data__

# %%
# code here

# %% [markdown]
# __1.5- Get a look (a plot) of the PCA on your data__

# %%
# code here

# %% [markdown]
# ## 2- Dimension reduction (T-SNE)

# %% [markdown]
# __2.1- Instantiate your TSNE method__

# %%
# code here

# %% [markdown]
# __2.2- Fit your data and transform it__

# %%
# code here

# %% [markdown]
# __2.3- Get a look on your TSNE transformation__

# %%
# code here

# %% [markdown]
# # Generating your Reviews Embedding Matrix

# %% [markdown]
# __1- For each reviews, agregate (average) the weight vector of terms it comprises__

# %%
# code here

# %% [markdown]
# __2- There you go, you build your first word2vec embedding matrix for further analysis__

# %%
# code here

# %% [markdown]
# __The End!__
